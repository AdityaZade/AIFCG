# %% [markdown]
# <a href="https://colab.research.google.com/github/AdityaZade/AIFCG/blob/main/Coloumn__Name_Extractrator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
lst2="ORDER_KEY	ACCOUNT_KEY	AGG_UNIT_CD	BASE_CURR_LIMIT_PRICE	BASE_CURR_ORDER_PRINCIPAL_AMT	BASE_CURR_STOP_PRICE	BASE_CURRENCY_CD	BUSINESS_DATE	CAPACITY	CAPACITY_CD	CHANNEL_CD	DARK_POOL_IND	DELIVERY_END_DATE	DELIVERY_START_DATE	DESK	DIRECTION_CD	EXCHANGE_CD	EXECUTING_REPRESENTATIVE_KEY	INSTRUCTION_TYPE_CD1	IS_CONTINUOUS	IS_DMA	IS_HELD	IS_INFORMED_CONSENT	IS_INSIDERS_ORDER	IS_SIDE_BY_SIDE	IS_VENUE_OVERRIDE	LEAVES_QUANTITY	MPID	ORDER_CLOSE_EXPIRE_DATE_TIME	ORDER_DATE_TIME	ORDER_ENTRY_DATE_TIME	ORDER_ID	ORDER_QUANTITY	ORDER_TERM_CD	ORDER_TYPE_CD	ORDER_VERSION	ORIG_CURR_LIMIT_PRICE	ORIG_CURR_ORDER_PRINCIPAL_AMT	ORIG_CURR_STOP_PRICE	ORIGINAL_CURRENCY_CD	PARENT_CHILD_TYPE	PARENT_ORDER_ID	PRICE_INSTRUCTION_CD	PRODUCT_KEY	RECORD_TYPE_CD	REG_NMS_EXEMPT_CD	REGION_CD	SOURCE_SYSTEM_CD	TIME_ZONE	TRADING_SERVICE_CD	TRANS_TYPE_CD	BASE_ORDER_DATE_TIME	BASE_ORDER_ENTRY_DATE_TIME	BASE_ORDER_CLOSE_EXP_DATE_TIME	TIME_ZONE_CD		"
lst3= "ACCOUNT_BROKER_FIRM_CODE	ADDRESS_LINE1	ADDRESS_LINE2	APARTMENT_SUITE_NUM	BUILDING_NUM	CITY	CLOSED_DATE	COUNTRY_CD	IS_APPROVED_BROKER	BROKER_FIRM_CONTACT_NUMBER	BROKER_FIRM_CRD	BROKER_FIRM_EIN_SSN	ACCOUNT_BROKER_FIRM_NAME	BROKER_FIRM_NFA	BROKER_FIRM_SEC	BROKER_FIRM_TYPE_CD	REGION_CD	REGULATOR_CD	ROUTING_NUM	ROW_UPDATE_DATE	STATE_PROVINCE	STREET	ZIP_POSTAL_CODE	BUSINESS_UNIT	"
lst1 ="EXECUTION_KEY	ACCOUNT_KEY	ACCRUED_INTEREST	AGG_UNIT_CD	ANNUALIZED_P_L	BASE_CURR_DAY_ABSOLUTE_P_L	BASE_CURR_DEAL_PREMIUM	BASE_CURR_EXE_PRICE	BASE_CURR_FEE_AMOUNT	BASE_CURR_NET_AMOUNT	BASE_CURR_NOTIONAL_AMOUNT	BASE_CURR_PAR_VALUE	BASE_CURR_PRIN_AMOUNT	BASE_CURR_SETTLEMENT_PRICE	BASE_CURR_TAX_AMOUNT	BASE_CURRENCY_CD	BASE_CURRENCY_COMMISSION	BLOCK_IND_CD	BROKER_REP_KEY	BUSINESS_DATE	CAPACITY_CD	CLEARING_FIRM_ID	COMMISSION_PCT	CONTRACT_TERM_CD	CONTROL_NUMBER	CORPORATE_SPREAD_RATE	CORRECTION_TYPE_CD	COUNTER_BASE_CURR_PRIN_AMOUNT	COUNTER_CURR_EXE_PRICE	COUNTER_CURR_PRIN_AMOUNT	COUNTER_CURRENCY_CD	COUNTERPARTY_ACCOUNT_KEY	COUNTERPARTY_CATEGORY_CD	COUNTERPARTY_MEMBER_CD	COUNTERPARTY_REP_ID	COVERED_IND	CROSS_TYPE_CD	DESK	DIRECTION_CD	EXCHANGE_CD	EXE_QUANTITY	EXECUTING_REPRESENTATIVE_KEY	EXECUTION_DATE_TIME	EXECUTION_ID	EXECUTION_SOURCE_ID	FEE_PCT	FORWARD_PRICE	INTERNAL_RATE	IS_AVERAGE_PRICE	IS_DMA	IS_EXERCISED	IS_HRR	IS_PRE_CLEARED	IS_SOLICITED	IS_SYNDICATE	LEAVES_QUANTITY	MATCH_TRADE_NUM	MEMBER_CD	OFFERING_TYPE_CD	ORDER_KEY	ORDER_TYPE_CD	ORIG_CURR_DAY_ABSOLUTE_P_L	ORIG_CURR_DEAL_PREMIUM	ORIG_CURR_EXE_PRICE	ORIG_CURR_NET_AMOUNT	ORIG_CURR_NOTIONAL_AMOUNT	ORIG_CURR_PREMIUM_DISCOUNT	ORIG_CURR_PRIN_AMOUNT	ORIG_CURR_SETTLEMENT_PRICE	ORIG_CURR_TAX_AMOUNT	ORIGINAL_CURR_FEE_AMOUNT	ORIGINAL_CURRENCY_CD	ORIGINAL_CURRENCY_COMMISSION	ORIGINAL_EXECUTION_ID	PARENT_ORDER_ID	PRINCIPAL_SUPERVISORY_APPROVAL	PRODUCT_KEY	RECORD_TYPE_CD	REGION_CD	REPO_RATE	RISKLESS_PRINCIPAL_IND	ROW_UPDATE_DATE	SEQUENCE_NUMBER	SETTLE_DATE	SETTLEMENT_QTY	SETTLEMENT_TYPE_CD	SOURCE_SYSTEM_CD	SPOT_FORWARD_IND	SPREAD	SPREAD_PCT	SWAP_DEAL_ID	TAX_PERCENTAGE	TRADING_SERVICE_CD	TRANS_TYPE_CD	BASE_EXECUTION_DATE_TIME	BASE_ROW_UPDATE_DATE	TIME_ZONE_CD	"
lstq="ACCOUNT_KEY	ACCOUNT_SHORT_NAME	ACCT_CATEGORY_CD	ACCT_CLASSIFICATION_CD	ACCT_CLOSE_DATE	ACCT_CURR_CREDIT_LIMIT	ACCT_CURR_ST_ACCOUNT_ACTIVITY	ACCT_CURR_ST_ACCOUNT_VALUE	ACCT_CURR_ST_LIQUID_NET_WORTH	ACCT_CURR_ST_TOTAL_NET_WORTH	ACCT_CURRENCY_CD	ACCT_FIRST_NAME	ACCT_LAST_NAME	ACCT_MAIDEN_NAME	ACCT_MAIN_ADDRESS	ACCT_MIDDLE_NAME	ACCT_NUM	ACCT_OPEN_DATE	ACCT_OTHER_NAME	ACCT_STATUS_CD	ACCT_TYPE_CD	ADDITIONAL_INVEST_OBJECTIVE_1	ADDITIONAL_INVEST_OBJECTIVE_2	ADDITIONAL_INVEST_OBJECTIVE_3	AGG_UNIT_CATEGORY	AGG_UNIT_CD	APPROVE_DATE	AVG_BALANCE	BASE_CURR_CREDIT_LIMIT	BASE_CURR_ST_ACCOUNT_ACTIVITY	BASE_CURR_ST_ACCOUNT_VALUE	BASE_CURR_ST_LIQUID_NET_WORTH	BASE_CURR_ST_TOTAL_NET_WORTH	BASE_CURRENCY_CD	BRANCH_KEY	ACCOUNT_BROKER_FIRM_CODE	COUNTRY_CD	BUSINESS_OWNER_NAME	BUSINESS_UNIT	CHANNEL_OF_ACCOUNT_OPENING_CD	CLEARING_FIRM_ID	CLIENT_SOPHISTICATION_CD	COMMISSION_GROUP_CD	CUSTOM_FIELD_1	CUSTOM_FIELD_2	CUSTOM_FIELD_3	CUSTOM_FIELD_4	CUSTOM_FIELD_5	CUSTOM_RISK_FACTOR1	CUSTOM_RISK_FACTOR2	CUSTOM_RISK_FACTOR3	CUSTOM_RISK_FACTOR4	DISBURSMENT_AMOUNT	DIVIDEND_INDICATOR	EMPLOYEE_ID	FACE_AMOUNT	FEE_BASED_ENROLL_DATE	FEE_BASED_TERM_DATE	HOUSEHOLD_ID	INITIAL_SOURCE_OF_FUNDS_CD	INVESTMENT_ADVISE_IND	INVESTMENT_EXPERIENCE_COM	INVESTMENT_EXPERIENCE_DEFAULT	INVESTMENT_EXPERIENCE_EQ	INVESTMENT_EXPERIENCE_FI	INVESTMENT_EXPERIENCE_FOREX	INVESTMENT_EXPERIENCE_MUF	INVESTMENT_EXPERIENCE_OPT	INVESTMENT_OBJECTIVE_CD	INVESTMENT_TIME_HORIZON	IS_ACTIVE	IS_ANONYMOUS_ACCT	IS_DISCRETIONARY	IS_DVP_RVP	IS_EMPLOYEE_ACCOUNT	IS_ERROR_ACCOUNT	IS_FOREIGN_FINANCIAL_ORG	IS_INSTITUTIONAL	IS_MANAGED_ACCOUNT	IS_MARGIN_ACCT	IS_NON_PHYSICAL_ADDRESS	IS_NON_RESIDENT	IS_ONLINE_ACCOUNT	IS_OPTION_APPROVED	IS_PASSIVELY_MANAGED	IS_PEP	IS_QIB	IS_SINGLE_JOINT	IS_SOFT_DOLLAR	IS_STREET_SIDE	IS_SUSPECT	IS_TRADING_EXPERIENCE	IS_VA_ACCOUNT_FLAG	ISSUE_STATE	ISSUER_ID	LAST_REVIEW_DATE	LIQUIDITY_NEEDS	MAIL_CODE	MASTER_ACCOUNT_KEY	MATURITY_DATE	NUMBER_OF_LOANS	ONGOING_SOURCE_OF_FUNDS_CD	OPTION_APPROVAL_LEVEL_CD	PAYMENT_DUE_DATE	PAYMENT_SCHEDULE	PREMIUM_AMOUNT	PRIMARY_PARTY_KEY	PRIMARY_REPRESENTATIVE_KEY	REGION_CD	REINSTATEMENT_DATE	RISK_LEVEL	RISK_TOLERANCE_CD	ROW_UPDATE_DATE	SECTOR_CD	SPLIT_RR_IND	STATE_529_CD	SURRENDER_AMOUNT	SURRENDER_PENALTY_AMOUNT	TAX_BRACKET_CD	TENANT_CD	VERIFICATION_DATE	VERIFICATION_STATUS	ACCOUNT_APPROVE_DATE	"
lst="PRODUCT_KEY	ASSET_TYPE_IND	BOND_COUPON_FIRST_DATE	BOND_INTEREST_RATE	BOND_MATURITY_DATE	CALL_DATE	CALL_PRICE	CALL_PUT_IND	COMMODITY_CD	COMPOSITE_PRODUCT_FLAG	CONVERSION_FACTOR	COUNTRY_CD	CREDIT_RATING	CUSIP_NUM	CUSTOM_PRODUCT_XREF_CD	CUSTOM_PRODUCT_XREF_TYPE	CUSTOM_RATING	CUSTOM_RATING_TYPE	DA_RT_IND	DELIVERY_END_DAY	DELIVERY_END_TIME	DELIVERY_START_DAY	DELIVERY_START_TIME	DURATION	EXPIRATION_DATE	FITCH_RATING	GRADE	HOLDING_PERIOD_DAYS	INVESTMENT_END_TYPE_IND	IS_ACTIVE	IS_EXEMPT_REGS	IS_PRIVATE_OFFERING	IS_REGS	IS_RULE_144A	IS_UNDER_RESTRICTION_REGS	ISIN_NUM	ISSUE_DATE	ISSUER_ID	ISSUER_NAME	LOCATION_CD	MARKET_MAJOR_INDEX_CD	MF_FAMILY_CD	MF_INVESTMENT_OBJ_CD	MF_LOAD_CD	MF_RATING	MF_SHARE_CLASS_CD	MF_TYPE	MOODY_RATING	MORNING_STAR_RATING	OPTION_CLASS	OPTION_DESIGNATION	OPTION_SERIES	OUTSTANDING_UNDERLYING_SHARES	PAR_VALUE	PIPELINE_CD	PRICING	PRIMARY_EXCHANGE	CURRENCY_CD	PRODUCT_BETA	PRODUCT_CLASSIFICATION_CD	PRODUCT_DESC_LINE_1	PRODUCT_DESC_LINE_2	PRODUCT_NAME	PRODUCT_SECTOR	PRODUCT_SUB_TYPE_CD	PRODUCT_TYPE_CD	ROW_UPDATE_DATE	SEDOL_NUM	SP_RATING	STRIKE_PRICE	SYMBOL	TYPE_AMERICAN_EUROPEAN	UNDERLYING_SEC_PRODUCT_KEY	TEST_PROD	TEST_PROD2	TEST_PROD3	"
lst="PENSION_PLAN_ID	EMPLOYEE_ID	PLAN_TYPE_CODE	PLAN_TYPE_DESC	PLAN_CODE	PLAN_DESC	PERCENT_REG_POST_TAX	PERCENT_REG_PRE_TAX	PERCENT_REG_REF_PERIOD	PERCENT_BONUS_POST_TAX	PERCENT_BONUS_PRE_TAX	"
print( lst.split())
for idx,item in enumerate (lst.split(),start=1):
   print("<record id="+"\""+str(item)+"\""+" index="+"\""+str(idx-1)+"\""+"/>")
# Out:
# ['PENSION_PLAN_ID', 'EMPLOYEE_ID', 'PLAN_TYPE_CODE', 'PLAN_TYPE_DESC', 'PLAN_CODE', 'PLAN_DESC', 'PERCENT_REG_POST_TAX', 'PERCENT_REG_PRE_TAX', 'PERCENT_REG_REF_PERIOD', 'PERCENT_BONUS_POST_TAX', 'PERCENT_BONUS_PRE_TAX']
# <record id="PENSION_PLAN_ID" index="0"/>
# <record id="EMPLOYEE_ID" index="1"/>
# <record id="PLAN_TYPE_CODE" index="2"/>
# <record id="PLAN_TYPE_DESC" index="3"/>
# <record id="PLAN_CODE" index="4"/>
# <record id="PLAN_DESC" index="5"/>
# <record id="PERCENT_REG_POST_TAX" index="6"/>
# <record id="PERCENT_REG_PRE_TAX" index="7"/>
# <record id="PERCENT_REG_REF_PERIOD" index="8"/>
# <record id="PERCENT_BONUS_POST_TAX" index="9"/>
# <record id="PERCENT_BONUS_PRE_TAX" index="10"/>

# %%
list = " TARGET.accrued_interest = ISNULL(TRY_CAST(SOURCE.ACCRUED_INTEREST  as decimal(15,3)),NULL) ,TARGET.agg_unit_cd = SOURCE.AGG_UNIT_CD ,TARGET.annualized_p_l = ISNULL(TRY_CAST(SOURCE.ACCRUED_INTEREST  as decimal(15,3)),NULL) ,TARGET.base_curr_day_absolute_p_l= ISNULL(TRY_CAST(SOURCE.BASE_CURR_DAY_ABSOLUTE_P_L  as decimal(15,3)),NULL) ,TARGET.base_curr_deal_premium=ISNULL(TRY_CAST(OURCE.BASE_CURR_DEAL_PREMIUM  as decimal(15,3)),NULL)  ,TARGET.base_curr_exe_price= ISNULL(TRY_CAST(SOURCE.BASE_CURR_EXE_PRICE  as decimal(15,3)),NULL) ,TARGET.base_curr_fee_amount=ISNULL(TRY_CAST(SOURCE.BASE_CURR_FEE_AMOUNT  as decimal(15,3)),NULL)  ,TARGET.base_curr_net_amount= ISNULL(TRY_CAST(SOURCE.BASE_CURR_NET_AMOUNT  as decimal(15,3)),NULL) ,TARGET.base_curr_notional_amount= ISNULL(TRY_CAST(SOURCE.BASE_CURR_NOTIONAL_AMOUNT  as decimal(15,3)),NULL) ,TARGET.base_curr_par_value=ISNULL(TRY_CAST(SOURCE.BASE_CURR_PAR_VALUE  as decimal(15,3)),NULL)  ,TARGET.base_curr_prin_amount=ISNULL(TRY_CAST(SOURCE.BASE_CURR_PRIN_AMOUNT  as decimal(15,3)),NULL)  ,TARGET.base_curr_settlement_price=ISNULL(TRY_CAST(SOURCE.BASE_CURR_SETTLEMENT_PRICE  as decimal(15,3)),NULL)  ,TARGET.base_curr_tax_amount=ISNULL(TRY_CAST(SOURCE.BASE_CURR_TAX_AMOUNT  as decimal(15,3)),NULL)  ,TARGET.base_currency_cd= SOURCE.BASE_CURRENCY_CD,TARGET.base_currency_commission= ISNULL(TRY_CAST(SOURCE.BASE_CURRENCY_COMMISSION as decimal(15,3)),NULL),TARGET.block_ind_cd= SOURCE.BLOCK_IND_CD,TARGET.broker_rep_key=SOURCE.BROKER_REP_KEY ,TARGET.business_date=ISNULL(TRY_CONVERT(datetime,SOURCE.BUSINESS_DATE 105),NULL) ,TARGET.capacity_cd= SOURCE.CAPACITY_CD,TARGET.clearing_firm_id= SOURCE.CLEARING_FIRM_ID,TARGET.commission_pct= ISNULL(TRY_CAST(SOURCE.COMMISSION_PCT  as decimal(15,3)),NULL),TARGET.contract_term_cd= SOURCE.CONTRACT_TERM_CD,TARGET.control_number=SOURCE.CONTROL_NUMBER,TARGET.corporate_spread_rate = ISNULL(TRY_CAST(SOURCE.CORPORATE_SPREAD_RATE  as decimal(15,3)),NULL) ,TARGET.correction_type_cd = SOURCE.CORRECTION_TYPE_CD ,TARGET.counter_base_curr_prin_amount= ISNULL(TRY_CAST(SOURCE.COUNTER_BASE_CURR_PRIN_AMOUNT  as decimal(15,3)),NULL) ,TARGET.counter_curr_exe_price= ISNULL(TRY_CAST(SOURCE.COUNTER_CURR_EXE_PRICE  as decimal(15,3)),NULL) ,TARGET.counter_curr_prin_amount= ISNULL(TRY_CAST(SOURCE.COUNTER_CURR_PRIN_AMOUNT  as decimal(15,3)),NULL) ,TARGET.counter_currency_cd=SOURCE.COUNTER_CURRENCY_CD,TARGET.counterparty_account_key= SOURCE.COUNTERPARTY_ACCOUNT_KEY,TARGET.counterparty_category_cd= SOURCE.COUNTERPARTY_CATEGORY_CD,TARGET.counterparty_member_cd= SOURCE.COUNTERPARTY_MEMBER_CD,TARGET.counterparty_rep_id= SOURCE.COUNTERPARTY_REP_ID,TARGET.covered_ind= SOURCE.COVERED_IND,TARGET.cross_type_cd= SOURCE.CROSS_TYPE_CD,TARGET.desk= SOURCE.DESK,TARGET.direction_cd= SOURCE.DIRECTION_CD,TARGET.exchange_cd= SOURCE.EXCHANGE_CD ,TARGET.exe_quantity=ISNULL(TRY_CAST(SOURCE.EXE_QUANTITY  as decimal(15,3)),NULL)  ,TARGET.executing_representative_key= SOURCE.EXECUTING_REPRESENTATIVE_KEY ,TARGET.execution_id=SOURCE.EXECUTION_ID ,TARGET.execution_source_id=SOURCE.EXECUTION_SOURCE_ID ,TARGET.fee_pct=ISNULL(TRY_CAST(SOURCE.FEE_PCT  as decimal(15,3)),NULL)  ,TARGET.forward_price= ISNULL(TRY_CAST(SOURCE.FORWARD_PRICE  as decimal(15,3)),NULL) ,TARGET.internal_rate= ISNULL(TRY_CAST(SOURCE.INTERNAL_RATE  as decimal(15,3)),NULL) ,TARGET.is_average_price= ISNULL(TRY_CAST(SOURCE.IS_AVERAGE_PRICE AS SMALLINT),NULL),TARGET.is_dma= ISNULL(TRY_CAST(SOURCE.IS_DMAY AS SMALLINT),NULL),TARGET.is_exercised= ISNULL(TRY_CAST(SOURCE.IS_EXERCISED AS SMALLINT),NULL),TARGET.is_hrr= ISNULL(TRY_CAST(SOURCE.IS_HRR AS SMALLINT),NULL),TARGET.is_pre_cleared= ISNULL(TRY_CAST(SOURCE.IS_PRE_CLEARED AS SMALLINT),NULL),TARGET.is_solicited= ISNULL(TRY_CAST(SOURCE.IS_SOLICITED AS SMALLINT),NULL),TARGET.is_syndicate= ISNULL(TRY_CAST(SOURCE.IS_SYNDICATE AS SMALLINT),NULL),TARGET.leaves_quantity= ISNULL(TRY_CAST(SOURCE.LEAVES_QUANTITY as decimal(15,3)),NULL),TARGET.match_trade_num= SOURCE.MATCH_TRADE_NUM,TARGET.member_cd= SOURCE.MEMBER_CD,TARGET.offering_type_cd= SOURCE.OFFERING_TYPE_CD,TARGET.order_key= SOURCE.ORDER_KEY,TARGET.order_type_cd= SOURCE.ORDER_TYPE_CD,TARGET.orig_curr_day_absolute_p_l= ISNULL(TRY_CAST(SOURCE.ORIG_CURR_DAY_ABSOLUTE_P_L as decimal(15,3)),NULL),TARGET.orig_curr_deal_premium= ISNULL(TRY_CAST(SOURCE.ORIG_CURR_DEAL_PREMIUMT as decimal(15,3)),NULL),TARGET.orig_curr_exe_price= ISNULL(TRY_CAST(SOURCE.ORIG_CURR_EXE_PRICE as decimal(15,3)),NULL),TARGET.orig_curr_net_amount=ISNULL(TRY_CAST(SOURCE.ORIG_CURR_NET_AMOUNTas decimal(15,3)),NULL) ,TARGET.orig_curr_notional_amount=ISNULL(TRY_CAST(SOURCE.ORIG_CURR_NOTIONAL_AMOUNT as decimal(15,3)),NULL) ,TARGET.orig_curr_premium_discount=ISNULL(TRY_CAST(SOURCE.ORIG_CURR_PREMIUM_DISCOUNT as decimal(15,3)),NULL) ,TARGET.orig_curr_prin_amount= ISNULL(TRY_CAST(SOURCE.ORIG_CURR_PRIN_AMOUNT as decimal(15,3)),NULL),TARGET.orig_curr_settlement_price= ISNULL(TRY_CAST(SOURCE.ORIG_CURR_SETTLEMENT_PRICE as decimal(15,3)),NULL),TARGET.orig_curr_tax_amount= ISNULL(TRY_CAST(SOURCE.ORIG_CURR_TAX_AMOUNT as decimal(15,3)),NULL),TARGET.original_curr_fee_amount= ISNULL(TRY_CAST(SOURCE.ORIGINAL_CURR_FEE_AMOUNT as decimal(15,3)),NULL),TARGET.original_currency_cd=SOURCE.ORIGINAL_CURRENCY_CD,TARGET.original_currency_commission= ISNULL(TRY_CAST(SOURCE.ORIGINAL_CURRENCY_COMMISSION as decimal(15,3)),NULL),TARGET.original_execution_id=SOURCE.ORIGINAL_EXECUTION_ID ,TARGET.parent_order_id= SOURCE.PARENT_ORDER_ID ,TARGET.principal_supervisory_approval= ISNULL(TRY_CAST(SOURCE.PRINCIPAL_SUPERVISORY_APPROVAL AS SMALLINT),NULL),TARGET.record_type_cd= SOURCE.RECORD_TYPE_CD,TARGET.region_cd= SOURCE.REGION_CD,TARGET.repo_rate= ISNULL(TRY_CAST(SOURCE.REPO_RATE as decimal(15,3)),NULL) ,TARGET.riskless_principal_ind= SOURCE.RISKLESS_PRINCIPAL_IND ,TARGET.row_update_date=ISNULL(TRY_CONVERT(datetime,SOURCE.ROW_UPDATE_DATE, 105),NULL) ,TARGET.sequence_number=ISNULL(TRY_CAST(SOURCE.SEQUENCE_NUMBER as decimal(15,3)),NULL) ,TARGET.settle_date= ISNULL(TRY_CONVERT(datetime,SOURCE.SETTLE_DATE, 105),NULL) ,TARGET.settlement_qty= ISNULL(TRY_CAST(SOURCE.SETTLEMENT_QTY as decimal(15,3)),NULL) ,TARGET.settlement_type_cd= SOURCE.SETTLEMENT_TYPE_CD,TARGET.source_system_cd= SOURCE.SOURCE_SYSTEM_CD,TARGET.spot_forward_ind= SOURCE.SPOT_FORWARD_IND,TARGET.spread= ISNULL(TRY_CAST(SOURCE.SPREAD as decimal(15,3)),NULL),TARGET.spread_pct= ISNULL(TRY_CAST(SOURCE.SPREAD_PCT as decimal(15,3)),NULL),TARGET.swap_deal_id= SOURCE.SWAP_DEAL_ID,TARGET.tax_percentage= ISNULL(TRY_CAST(SOURCE.TAX_PERCENTAGE as decimal(15,3)),NULL),TARGET.trading_service_cd= SOURCE.TRADING_SERVICE_CD,TARGET.trans_type_cd= SOURCE.TRANS_TYPE_CD,,TARGET.base_execution_date_time= ISNULL(TRY_CONVERT(datetime,SOURCE.BASE_EXECUTION_DATE_TIME, 105),NULL) ,TARGET.base_row_update_date= ISNULL(TRY_CONVERT(datetime,SOURCE.BASE_ROW_UPDATE_DATE, 105),NULL),TARGET.time_zone_cd= SOURCE.TIME_ZONE_CD,"
str = "TARGET.accrued_interest = ISNULL(TRY_CAST(SOURCE.ACCRUED_INTEREST  as decimal(15,3)),NULL) "
res = str.split("=", 1)
print(res[1])
# Out:
#  ISNULL(TRY_CAST(SOURCE.ACCRUED_INTEREST  as decimal(15,3)),NULL)

# %%
lst =  "POSITION_DATE	ACCOUNT_KEY	PRODUCT_KEY	POSITION_TYPE_CD	LONG_SHORT_IND	CONTRACT_KEY	PORTFOLIO	ACCT_CURRENCY_PRICE	ACCT_CURRENCY_VALUE	AGG_UNIT_CD	BASE_CURRENCY_CD	BASE_CURRENCY_PRICE	BASE_CURRENCY_VALUE	COMPOSITE_PRODUCT_ID	INSTRUMENT_PERIOD_CD	LEGAL_ENTITY_ID	ORIGINAL_CURRENCY_CD	ORIGINAL_CURRENCY_PRICE	ORIGINAL_CURRENCY_VALUE	QUANTITY	REGION_CD	ROW_UPDATE_DATE	"

lst=lst.lower()
print( lst.split())
for i in lst.split():
   print(i)
# Out:
# ['position_date', 'account_key', 'product_key', 'position_type_cd', 'long_short_ind', 'contract_key', 'portfolio', 'acct_currency_price', 'acct_currency_value', 'agg_unit_cd', 'base_currency_cd', 'base_currency_price', 'base_currency_value', 'composite_product_id', 'instrument_period_cd', 'legal_entity_id', 'original_currency_cd', 'original_currency_price', 'original_currency_value', 'quantity', 'region_cd', 'row_update_date']
# position_date
# account_key
# product_key
# position_type_cd
# long_short_ind
# contract_key
# portfolio
# acct_currency_price
# acct_currency_value
# agg_unit_cd
# base_currency_cd
# base_currency_price
# base_currency_value
# composite_product_id
# instrument_period_cd
# legal_entity_id
# original_currency_cd
# original_currency_price
# original_currency_value
# quantity
# region_cd
# row_update_date

# %%
lst =  "POSITION_DATE	ACCOUNT_KEY	PRODUCT_KEY	POSITION_TYPE_CD	LONG_SHORT_IND	CONTRACT_KEY	PORTFOLIO	ACCT_CURRENCY_PRICE	ACCT_CURRENCY_VALUE	AGG_UNIT_CD	BASE_CURRENCY_CD	BASE_CURRENCY_PRICE	BASE_CURRENCY_VALUE	COMPOSITE_PRODUCT_ID	INSTRUMENT_PERIOD_CD	LEGAL_ENTITY_ID	ORIGINAL_CURRENCY_CD	ORIGINAL_CURRENCY_PRICE	ORIGINAL_CURRENCY_VALUE	QUANTITY	REGION_CD	ROW_UPDATE_DATE	"
for i in lst.split():
  print("SOURCE."+i)
# Out:
# SOURCE.POSITION_DATE
# SOURCE.ACCOUNT_KEY
# SOURCE.PRODUCT_KEY
# SOURCE.POSITION_TYPE_CD
# SOURCE.LONG_SHORT_IND
# SOURCE.CONTRACT_KEY
# SOURCE.PORTFOLIO
# SOURCE.ACCT_CURRENCY_PRICE
# SOURCE.ACCT_CURRENCY_VALUE
# SOURCE.AGG_UNIT_CD
# SOURCE.BASE_CURRENCY_CD
# SOURCE.BASE_CURRENCY_PRICE
# SOURCE.BASE_CURRENCY_VALUE
# SOURCE.COMPOSITE_PRODUCT_ID
# SOURCE.INSTRUMENT_PERIOD_CD
# SOURCE.LEGAL_ENTITY_ID
# SOURCE.ORIGINAL_CURRENCY_CD
# SOURCE.ORIGINAL_CURRENCY_PRICE
# SOURCE.ORIGINAL_CURRENCY_VALUE
# SOURCE.QUANTITY
# SOURCE.REGION_CD
# SOURCE.ROW_UPDATE_DATE

# %%
# Out:
#    text
# text
# text
